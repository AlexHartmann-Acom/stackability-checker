# %%
import importlib
import factories.sx as sx
import stackability.datatypes as dt
importlib.reload(sx)
importlib.reload(dt)
# Out:
# <module 'datatypes' from '/Users/alexhartmann/Dev/Anssems/stackability-checker/datatypes.py'>

# %%
import factories.sx as sx
import stackability.datatypes as dt

stack_result = sx.stack(
    [
        dt.Trailer(
            sku='a',
            width=120,
            heigth=180,
            length=405,
            axles=2,
            model_name='MSX'
        ),
        ...
        
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 sx.stack(
#       2     [
# ----> 3         dt.Trailer(
#       4             sku='a',
#       5             width=120,
#       6             heigth=180,
#       7             length=405,
#       8             axles=2,
#       9             model_name='MSX'
#      10         ),
#      11         ...
#      12
#      13     ]
#      14 )
#
# TypeError: __init__() got an unexpected keyword argument 'heigth'
